# %%
import pandas as pd
import numpy as np

# %%
pair_counts = pd.read_csv("/ssd1/jueon/wj/detoxicity_model/molecularACE_ver/pair_counts.csv")

# %%
pair_counts.head(2)
# Out:
#          dataset                             endpoint  n_pairs
# 0  skin_reaction                        skin_reaction     2680
# 1     toxcast_df  toxcast_APR_HepG2_MitoMembPot_1h_dn      156

# %%
print(pair_counts['dataset'].value_counts())
# Out:
# dataset
# toxcast_df             617
# tox21_df                12
# carcinogens_lagunin      1
# skin_reaction            1
# herg                     1
# clintox                  1
# ames                     1
# diril                    1
# dictrank                 1
# dilist                   1
# herg_karim               1
# herg_central             1
# Name: count, dtype: int64

# %%
len(pair_counts) - len(pair_counts[pair_counts['dataset'] == 'toxcast'])
# Out:
# 639
