# %%
import pandas as pd

# %%
df = pd.read_csv("/ssd1/jueon/wj/detoxicity_model/ace_safe_ver/viz_property_delta/outlier_summary_iqr_1p5.csv")

# %%
df
# Out:
#   property          column  valid_n         q1         q3        iqr  \
# 0       MW    delta_abs_MW    63251  15.922144  76.919222  60.997079
# 1     logP  delta_abs_logP    63251   0.390100   1.654500   1.264400
# 2     TPSA  delta_abs_TPSA    63251   5.790000  31.510000  25.720000
# 3      HBD   delta_abs_HBD    63251   0.000000   1.000000   1.000000
# 4      HBA   delta_abs_HBA    63251   0.000000   1.000000   1.000000
# 5     RotB  delta_abs_RotB    63251   0.000000   3.000000   3.000000
#
#    lower_fence  upper_fence  outlier_n  outlier_ratio
# 0   -75.573475   168.414841       2777       0.043904
# 1    -1.506500     3.551100       2589       0.040932
# 2   -32.790000    70.090000       2455       0.038814
# 3    -1.500000     2.500000       2605       0.041185
# 4    -1.500000     2.500000       4986       0.078829
# 5    -4.500000     7.500000       1768       0.027952
