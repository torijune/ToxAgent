# %%
# Source - https://stackoverflow.com/a/43128422
# Posted by ImportanceOfBeingErnest
# Retrieved 2026-03-12, License - CC BY-SA 3.0

import matplotlib.pyplot as plt

for i in range(30):
    plt.figure()
    plt.plot(range(i+3), range(i+3))
    plt.grid('on')
    plt.close()

plt.show() # doesn't show anything since no figure is open
